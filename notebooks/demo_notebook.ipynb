# %% [markdown]
# # Demo Jupyter Notebook on WE-validate

# %% [markdown]
# Usage:
#
# 1. Edit `config/config.yaml`
#
#     1. Choose validation `location`, `time`, `metrics`, and `levels`
#     2. Put datasets in the specified `path` in `config.yaml`
#
# 2. Run the following cells with `Shift` + `Return`/`Enter`
#
#     1. Comments start with `#`
#     2. The default of the `compare` function is running `config.yaml`. To run a different `config` file, simply declare it in the `compare` function, e.g. `compare('config_test.yaml')`

# %%
import os
import pathlib
import sys

sys.path.append(str(pathlib.Path(os.getcwd()).parent))

# main routine of we-validate
from wevalidate import compare

# %% [markdown]
# ## Main routine

# %%
# %load_ext autoreload
# %autoreload 2

compare()
# Out:
# validation start time: 2016-09-23 12:00:00
# validation end time: 2016-09-25 12:00:00
# location: {'lat': 45.57451, 'lon': -120.74734}
# baseline dataset: sodar
# variable: wind speed
#
# ######################### height a.g.l.: 40 m #########################
#
# ********** for sodar: **********
#
# detect masked value at 2016-09-23 16:10:00, convert to NaN
# detect masked value at 2016-09-23 16:20:00, convert to NaN
#
# read in sodar_ws from 2016-09-23 00:00:00 to 2016-09-25 23:50:00
# every 10 minutes, total of 432 files
#
# --- sodar_ws dataframe should have unique and continuous data ---
#
# ********** for wrf: **********
#
# read in wrf_ws from 2016-09-23 12:00:00 to 2016-09-25 12:00:00
# every 5 minutes, total of 577 files
#
# --- wrf_ws dataframe should have unique and continuous data ---
#
# aligning the 5-miniute comparison data (wrf_ws) to match the
# 10-minute baseline data (sodar_ws), at the end of the
# measurement period using the instance method
#
# ...

# %% [markdown]
# ## Testing with erroneous datasets

# %%
# %load_ext autoreload
# %autoreload 2

# testing on erroneous datasets
compare('config_test.yaml')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# validation start time: 2016-09-23 12:00:00
# validation end time: 2016-09-25 12:00:00
# location: {'lat': 45.57451, 'lon': -120.74734}
# baseline dataset: sodar
# variable: wind speed
#
# ######################### height a.g.l.: 40 m #########################
#
# ********** for sodar: **********
#
# read in sodar_ws from 2016-09-24 00:00:00 to 2016-09-25 23:50:00
# every 10 minutes, total of 284 files
#
# !!!!!!!!!!
# WARNING: sodar_ws DATA ENTRY NUMBER (284) DOES NOT MATCH DESIRED DATA LENGTH (288.0),
# WHICH IS DEFINED BY:
# DATA START TIME (2016-09-24 00:00:00),
# DATA END TIME (2016-09-25 23:50:00),
# AND USER-INPUT DATA FREQUENCY (10)
# !!!!!!!!!!
#
# DETECT 6 ROWS IN DATAFRAME ARE MISSING
# THEY ARE:
# ['2016-09-24 08:00:00' '2016-09-24 08:10:00' '2016-09-24 08:20:00'
#  '2016-09-24 08:30:00' '2016-09-24 08:40:00' '2016-09-24 08:50:00']
#
# ...

# %% [markdown]
# ## FINO2 data

# %%
# %load_ext autoreload
# %autoreload 2

compare('config_fino2ws.yaml')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# validation start time: 2020-10-04 00:00:00
# validation end time: 2020-10-11 00:00:00
# location: {'lat': 55.006928, 'lon': 13.154189}
# baseline dataset: fino2-82-ws
# variable: wind speed
#
# ######################### height a.g.l.: 82 m #########################
#
# ********** for fino2-82-ws: **********
#
# ********** for fino2-52-ws: **********
#
# evaluate windspeed_cup_82m_180deg, windspeed_cup_52m_180deg from 2020-10-04 00:05:00 to 2020-10-10 23:55:00
# every 10.0 minutes, total of 1008 time steps
#
# !!!!!!!!!!
# WARNING: DESIERED EVALUATION DURATION DOES NOT MATCH DATA DURATION
# DESIRED: FROM 2020-10-04 00:00:00 TO 2020-10-11 00:00:00
# DATA: FROM 2020-10-04 00:05:00 TO 2020-10-10 23:55:00
# !!!!!!!!!!
#
# !!!!!!!!!!
# WARNING: DATA FREQUENCY DOES NOT MATCH DESIRED EVALUATION PERIOD FREQUENCY
# SHOULD HAVE 1009.0 TIME STEPS IN DATA
# ONLY HAVE 1008 TIME STEPS IN DATA
# !!!!!!!!!!
#
# ...

# %%
# %load_ext autoreload
# %autoreload 2

compare('config_fino2wd.yaml')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# validation start time: 2020-10-04 00:00:00
# validation end time: 2020-10-11 00:00:00
# location: {'lat': 55.006928, 'lon': 13.154189}
# baseline dataset: fino2-71-wd
# variable: wind direction
#
# ######################### height a.g.l.: 71 m #########################
#
# ********** for fino2-71-wd: **********
#
# ********** for fino2-51-wd: **********
#
# evaluate winddirection_vane_71m_0deg, winddirection_vane_51m_0deg from 2020-10-04 00:05:00 to 2020-10-10 23:55:00
# every 10.0 minutes, total of 1008 time steps
#
# !!!!!!!!!!
# WARNING: DESIERED EVALUATION DURATION DOES NOT MATCH DATA DURATION
# DESIRED: FROM 2020-10-04 00:00:00 TO 2020-10-11 00:00:00
# DATA: FROM 2020-10-04 00:05:00 TO 2020-10-10 23:55:00
# !!!!!!!!!!
#
# !!!!!!!!!!
# WARNING: DATA FREQUENCY DOES NOT MATCH DESIRED EVALUATION PERIOD FREQUENCY
# SHOULD HAVE 1009.0 TIME STEPS IN DATA
# ONLY HAVE 1008 TIME STEPS IN DATA
# ...

# %% [markdown]
# ## Ramps

# %%
# %load_ext autoreload
# %autoreload 2

compare('config_ramp.yaml')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# validation start time: 2016-09-23 12:00:00
# validation end time: 2016-09-25 12:00:00
# location: {'lat': 45.57451, 'lon': -120.74734}
# baseline dataset: sodar
# variable: wind speed
#
# ######################### height a.g.l.: 80 m #########################
#
# ********** for sodar: **********
#
# detect masked value at 2016-09-25 02:00:00, convert to NaN
# detect masked value at 2016-09-25 02:10:00, convert to NaN
# detect masked value at 2016-09-23 16:10:00, convert to NaN
# detect masked value at 2016-09-23 16:20:00, convert to NaN
#
# read in sodar_ws from 2016-09-23 00:00:00 to 2016-09-25 23:50:00
# every 10 minutes, total of 432 files
#
# --- sodar_ws dataframe should have unique and continuous data ---
#
# ********** for wrf: **********
#
# read in wrf_ws from 2016-09-23 12:00:00 to 2016-09-25 12:00:00
# every 5 minutes, total of 577 files
#
# ...
